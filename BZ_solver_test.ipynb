# %%
'''
20231019: Indrasen Bhattacharya
Simple notebook to test the BZ module
'''

import BZ_solver

# %%
params_img = {}
params_img['imgSize'] = 201
params_img['conc_scale'] = 1e-3

params_img['alpha'] = 25
params_img['beta'] = 20
params_img['gamma'] = 20

params_img['dA'] = 0.2
params_img['dB'] = 0.2
params_img['dC'] = 0.1

params_img['isBlurred'] = False
params_img['loadPng'] = True
params_img['imgName'] = '20231018_testImg.png'
params_img['shape'] = None

params_img['tSteps'] = 300
params_img['dt'] = 0.1

params_img['species'] = [0]
params_img['t_arr'] = [0]

setup_img = BZ_solver.BZ_solver( params_img )
# Out:
# (962, 962, 4)
# (201, 201, 4)
# FINAL RESAMPLED AND CROPPED IMAGE:

# %%
setup_img.displForcing()

# %%
setup_img.solver_RK4()
# Out:
# TOTAL SOLVER TIME: 0.00979299983009696

# %%
vidName = '20231019_faceMorph.mp4'

setup_img.generateAnimation( species=0, fName=vidName, cmapName = 'cubehelix_r' )

# %%
setup_img.displResult(species = 1, cmapName='cubehelix_r')

# %%
setup_img.displResult(species = 0, cmapName='cubehelix_r')

# %%
setup_img.displTimeProgression( loc=[100, 100] )

# %%
dir(BZ_solver)
# Out:
# ['BZ_solver',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__warningregistry__',
#  'animation',
#  'clear_output',
#  'display',
#  'mpl',
#  'np',
#  'plt',
#  'sp',
#  'sys',
#  'time',
#  'timeit']
