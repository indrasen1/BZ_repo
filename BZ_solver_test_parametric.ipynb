# %%
'''
20231019: Indrasen Bhattacharya
Simple notebook to test the BZ module
'''

import BZ_solver

# %%
params_img = {}
params_img['imgSize'] = 201
params_img['conc_scale'] = 1e-2

params_img['alpha'] = 20
params_img['beta'] = 20
params_img['gamma'] = 20

params_img['dA'] = 1
params_img['dB'] = 1
params_img['dC'] = 1

params_img['isBlurred'] = False
params_img['loadPng'] = False
params_img['loadPng_allSpecies'] = False
params_img['shape'] = 'heart'
params_img['species'] = [0]
#params_img['imgNameList'] = ['20231018_testImg.png', '20230714_testImg.png', '20230722_heartAttempt2.png'] 
#params_img['shape'] = None

params_img['tSteps'] = 1000
params_img['dt'] = 0.03

#params_img['species'] = [0]
params_img['t_arr'] = [0]

setup_img = BZ_solver.BZ_solver( params_img )

# %%
setup_img.displForcing()
# Out:
# NUMBER OF FORCED SPECIES 1
# DISPLAYING FORCING FUNCTION FOR EACH SPECIES IN ORDER

# %%
setup_img.solver_RK4()
# Out:
# TOTAL SOLVER TIME: 0.008837166242301464

# %%
vidName = '20231102_heartMorph.mp4'

setup_img.generateAnimation( species=0, fName=vidName, cmapName = 'cubehelix' )

# %%
setup_img.displResult(species = 1, cmapName='cubehelix_r')

# %%
setup_img.displResult(species = 2, cmapName='cubehelix')

# %%
setup_img.displTimeProgression( loc=[100, 100] )

# %%
dir(BZ_solver)
# Out:
# ['BZ_solver',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__warningregistry__',
#  'animation',
#  'clear_output',
#  'display',
#  'mpl',
#  'np',
#  'plt',
#  'sp',
#  'sys',
#  'time',
#  'timeit']
